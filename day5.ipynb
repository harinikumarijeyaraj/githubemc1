# %%
print ("hi")
# Out:
# hi

# %%
a = input("experience: ")
b = input("skill: ")
c = input("location: ")

if a >= "1" and b == "python" and c == "chennai":
    print("Infosys")

elif a == "0" and b == "java" and c == "coimbatore":
    print("TCS")

elif a == "0" and b == "java" and c == "bangalore":
    print("Zoho")

elif a >= "1" and b == "python" and c == "chennai":
    print("Cognizant")

else:
    print("Not Eligible")
# Out:
# experience:  2
# skill:  python
# location:  chennai
# Infosys
