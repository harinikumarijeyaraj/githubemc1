# %%
#for loop 

for i in range (5):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#for loop
for i in range(3,6,9):
    print(i)
# Out:
# 3

# %%
a=[1,2,3,4,5,6]
for i in a:
    print (a)
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]

# %%
for x in range (2,10):
    if x==4:
        break
    print (x)
# Out:
# 2
# 3

# %%
s={6,5,6,6,2}

for i in s:
    print (i)
# Out:
# 2
# 5
# 6

# %%
for x in range (2,10):
    print(x)
    if x==4:
        break
# Out:
# 2
# 3
# 4

# %%
for x in range (2,10):
    if x==4:
        continue
    print (x)
# Out:
# 2
# 3
# 5
# 6
# 7
# 8
# 9

# %%
for x in range (2,10):
    print(x)
    if x==4:
        continue
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9

# %%
k=[1,3,5,6]
l=[]
for i in k:
    print (i)
# Out:
# 1
# 3
# 5
# 6

# %%
k=[1,3,5,6]
l=[]
for i in k:
    l.append(i)
    print(l)
# Out:
# [1]
# [1, 3]
# [1, 3, 5]
# [1, 3, 5, 6]

# %%
k=[1,3,5,6]
l=[]
for i in k:
    l.append(i)
print(l)
# Out:
# [1, 3, 5, 6]

# %%
k=[1,6,7,9,4,5,77,8,5,3]
l=[]
for i in k:
    if i%2!=0:
        l.append(i)
print(l)
# Out:
# [1, 7, 9, 5, 77, 5, 3]
