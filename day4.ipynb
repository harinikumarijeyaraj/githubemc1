# %% [markdown]
# logical operator

# %%
a=5
b=7
print (a and b)
# Out:
# 7

# %%
a=5
b=7
print (a or b)
# Out:
# 5

# %%
a=7

print (a<5)
# Out:
# False

# %% [markdown]
# identify operator

# %%
a= 547
b=256
print(a is b )
# Out:
# False

# %%
a=547
b=256
print(a is not b)
# Out:
# True

# %% [markdown]
# membership operator

# %%
a= 1,2,3,4
b= 2,4,6,8
print (2 in b)
# Out:
# True

# %%
a=5,6,7,8
b=1,2,3,4
print (4 not in b)
# Out:
# False

# %% [markdown]
# bitwise operator

# %%
a=32
b=24
print (a & b)
# Out:
# 0

# %%
a=32
b=24
print (a | b)
# Out:
# 56

# %%
a=6
print (~a)
# Out:
# -7

# %%
a=5
b=8
print (a^b)
# Out:
# 13
