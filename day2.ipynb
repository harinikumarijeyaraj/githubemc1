# %%
print ("hi")
# Out:
# hi

# %%
h=("hello java world")
print(h.replace("java","python"))
# Out:
# hello python world

# %%
h=("hello python world")
print(h.count("l"))
# Out:
# 3

# %%
h=("hello python world")
print(len(h))
# Out:
# 18

# %%
h=["a","b","c"]

print(",".join(h))
# Out:
# a,b,c

# %%
h=("12345")
print(h.isdigit())
# Out:
# True
